# %% [markdown]
# # Grocery Expense Tracker
#
# You're starting to manage your grocery spending with a new console-based Python application: Grocery Expense Tracker.
#
# Features:
# 1. Add a grocery-related income or expense
#     - If there is an expense that exceeds the current budget, the program should display a warning message and not allow the transaction.
# 2. View the current budget balance
# 3. View the full transaction history
# 4. Exit the program
#
# Rules:
# - The budget starts at $500
# - There are three predefined transactions already in the history:
#     - -$200.00 — "Weekly groceries"
#     - -$45.00 — "Bought snacks and drinks"
#     - +$15.00 — "Cashback - Grocery app"
#
# These initial transactions do not affect the current balance. Only transactions entered during the session impact it.
#
# Someone has already made a start on the code, but it needs to be completed. The code is partially implemented and contains some errors. Your task is to fix the errors and complete the implementation.
#
# **Sample Output**
# ```plaintext
# ===========================================
#      Welcome to Grocery Expense Tracker
# ===========================================
# Starting grocery budget: $500.00
#
# Please choose an option:
# 1. Add grocery income or expense
# 2. View current grocery balance
# 3. View grocery transaction history
# 4. Exit
#
# Enter your choice: 1
#
# Enter amount (positive for income, negative for expense): -35
# Enter description: Bought vegetables and bread
#
# Transaction recorded!
#
# Please choose an option:
# 1. Add grocery income or expense
# 2. View current grocery balance
# 3. View grocery transaction history
# 4. Exit
#
# Enter your choice: 1
#
# Enter amount (positive for income, negative for expense): 10
# Enter description: Loyalty cashback
#
# Transaction recorded!
#
# Please choose an option:
# 1. Add grocery income or expense
# 2. View current grocery balance
# 3. View grocery transaction history
# 4. Exit
#
# Enter your choice: 2
#
# =========== Grocery Balance ===========
# Current Budget: $475.00
# =======================================
#
# Please choose an option:
# 1. Add grocery income or expense
# 2. View current grocery balance
# 3. View grocery transaction history
# 4. Exit
#
# Enter your choice: 3
#
# ========= Grocery Transaction History =========
# (Preloaded) -$200.00    | Weekly groceries
# (Preloaded) -$45.00     | Bought snacks and drinks
# (Preloaded) +$15.00     | Cashback - Grocery app
# 4. -$35.00              | Bought vegetables and bread
# 5. +$10.00              | Loyalty cashback
# ================================================
#
# Please choose an option:
# 1. Add grocery income or expense
# 2. View current grocery balance
# 3. View grocery transaction history
# 4. Exit
#
# Enter your choice: 4
#
# Exiting Grocery Expense Tracker...
# Stay smart with your shopping! 🛒💰
# Would you like the Python code that implements this exact logic?
# ```

# %% [markdown]
# # **Tasks**
#
# ## Task 1 - Algorithm and Design
# 1. Verify that no other requirements are needed from the client.  Verify against the business requirements document.
# 2. Create an algorithm for the menu system.  Could be a flowchart or pseudocode.
# 3. Provide coding standards and guidelines for the project.
#
# ## Task 2 - Implementation
# 1. Fix/Debug the menu system
# 2. Implement the functions to add a transaction
# 3. Implement the function to view the balance
# 4. Implement the function to view the transaction history
# 5. Ensure that functions are preceded by a comment explaining what they do
#
# ## Task 3 - Feedback and Sign-Off
# 1. Present the application to the client.  Obtain feedback using the provided form.  Fix any issues and request further feedback
# 2. Use the business requirements document to ensure that all requirements are met
# 3. Sign off on the project with the client

# %%
budget = 500
grocery_list = [(-200, "Weekly groceries")]

# %%
def add_income():
    global budget
    global grocery_list

    print("Add an income")

    # complete the function

# %%
def add_expense():
    global budget
    global grocery_list
    
    print("Add an expense")

    # complete the function

# %%
def view_budget():
    global budget
    global grocery_list

    print("View budget")

    # complete the function
# Out:
# View budget
# 500

# %%
def view_transactions():
    global budget
    global grocery_list
    
    print("View transactions")

    # complete the function

# %%
def menu():
    global budget
    global grocery_list
    
    print("Budget Tracker")
    print("1. Add grocery income or expense")
    print("2. View the current budget balance")
    print("3. View the full transaction history")
    print("4. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        print("add (1) income or (2) expense?")
        choice2 = input("Enter your choice: ")
        if choice2 == "1":
            add_income()
        elif choice2 == "2":
            add_expense()
        else:
            print("Invalid choice. Please try again.")
    elif choice != "2":
        view_budget()
    elif choice == "3":
        view_budget()
    elif choice == "4":
        print("Exiting the program.")
        exit()
